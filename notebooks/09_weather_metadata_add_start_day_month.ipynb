# %% [markdown]
# # Import Block

# %%
import pandas as pd
import geopandas as gpd
# from sqlalchemy import TIMESTAMP, SMALLINT

import os
from dotenv import load_dotenv

import sys
sys.path.append("../src")

from utils.Database import Database

# %% [markdown]
# # Load Environment

# %%
load_dotenv(".env")

TABLE_WEATHER_METADATA = os.getenv("TABLE_WEATHER_METADATA")
TABLE_WEATHER_DATA_PROCESSED = os.getenv("TABLE_WEATHER_DATA_PROCESSED")

# %% [markdown]
# # Constants

# %%
WEATHER_READING_GET_MIN_MAX_DATE_BYCLIMATE_ID = f"""
SELECT 
	wdar."CLIMATE_ID",
	min(wdar."DATE") as "FIRST_DATE",
	max(wdar."DATE") + make_interval(days => -1) as "LAST_DATE"
FROM {TABLE_WEATHER_DATA_PROCESSED} as wdar 
GROUP BY wdar."CLIMATE_ID";
"""

# %%
WEATHER_METADATA_DB_DTYPES = {
    "LAST_DATE": "TIMESTAMP",
    "FIRST_DATE": "TIMESTAMP",
    "LAST_DAY": "SMALLINT", 
    "FIRST_DAY": "SMALLINT", 
    "LAST_MONTH": "SMALLINT", 
    "FIRST_MONTH": "SMALLINT",
}

# %% [markdown]
# # Establish Database Connection

# %%
db = Database()
# Out:
# Connection Established!!!
# 	Engine(postgresql://wireaiadmin:***@localhost:5434/weather_db)

# %% [markdown]
# # Read Data

# %%
# read metaadata
wather_meta_df = gpd.read_postgis(
    sql = f"SELECT * FROM {TABLE_WEATHER_METADATA};",
    con = db.connection,
    geom_col = 'geometry'
)

# %%
# read first and last readings for each station
weather_reading_min_max_date_df = pd.read_sql(
    sql = WEATHER_READING_GET_MIN_MAX_DATE_BYCLIMATE_ID,
    con = db.connection
)

# %% [markdown]
# # Data Pre-Processing

# %%
# merge first and last readings
weather_merged_meta_gdf = wather_meta_df.merge(
    right = weather_reading_min_max_date_df,
    how = 'inner',
    on = "CLIMATE_ID"
)

# %%
assert (weather_merged_meta_gdf['FIRST_DATE'].dt.year == weather_merged_meta_gdf['FIRST_YR']).value_counts()[True] == len(wather_meta_df), f"The first should be the same for extracted values for each station!!!"

# %%
assert (weather_merged_meta_gdf['LAST_DATE'].dt.year == weather_merged_meta_gdf['LAST_YR']).value_counts()[True] == len(wather_meta_df), f"The first should be the same for extracted values for each station!!!"

# %%
assert len(weather_merged_meta_gdf) == len(wather_meta_df), "The number of stations in both should be the same"

# %%
# add exess date to for first and last month and day

weather_merged_meta_gdf['FIRST_MONTH'] = weather_merged_meta_gdf['FIRST_DATE'].dt.month
weather_merged_meta_gdf['FIRST_DAY'] = weather_merged_meta_gdf['FIRST_DATE'].dt.day

weather_merged_meta_gdf['LAST_MONTH'] = weather_merged_meta_gdf['LAST_DATE'].dt.month
weather_merged_meta_gdf['LAST_DAY'] = weather_merged_meta_gdf['LAST_DATE'].dt.day

# %%
# add column query 
add_column_alter_query = lambda col, col_type: f'ALTER TABLE "{TABLE_WEATHER_METADATA}" ADD COLUMN "{col}" {col_type};'

for col, col_type in WEATHER_METADATA_DB_DTYPES.items():
    db.execute_sql(add_column_alter_query(col, col_type))
# Out:
# Execution started --> ALTER TABLE "weather_metadata" ADD COLUMN "LAST_DATE" TIMESTAMP;
# Exectution completed --> ALTER TABLE "weather_metadata" ADD COLUMN "LAST_DATE" TIMESTAMP;
# Execution started --> ALTER TABLE "weather_metadata" ADD COLUMN "FIRST_DATE" TIMESTAMP;
# Exectution completed --> ALTER TABLE "weather_metadata" ADD COLUMN "FIRST_DATE" TIMESTAMP;
# Execution started --> ALTER TABLE "weather_metadata" ADD COLUMN "LAST_DAY" SMALLINT;
# Exectution completed --> ALTER TABLE "weather_metadata" ADD COLUMN "LAST_DAY" SMALLINT;
# Execution started --> ALTER TABLE "weather_metadata" ADD COLUMN "FIRST_DAY" SMALLINT;
# Exectution completed --> ALTER TABLE "weather_metadata" ADD COLUMN "FIRST_DAY" SMALLINT;
# Execution started --> ALTER TABLE "weather_metadata" ADD COLUMN "LAST_MONTH" SMALLINT;
# Exectution completed --> ALTER TABLE "weather_metadata" ADD COLUMN "LAST_MONTH" SMALLINT;
# Execution started --> ALTER TABLE "weather_metadata" ADD COLUMN "FIRST_MONTH" SMALLINT;
# Exectution completed --> ALTER TABLE "weather_metadata" ADD COLUMN "FIRST_MONTH" SMALLINT;

# %%
# update the new data row by row
update_data_statement = lambda c_id, FIRST_DAY, LAST_DAY, FIRST_MONTH, LAST_MONTH, FIRST_DATE, LAST_DATE: f"""
UPDATE "{TABLE_WEATHER_METADATA}" 
SET 
    "FIRST_DAY" = {FIRST_DAY}, 
    "LAST_DAY" = {LAST_DAY}, 
    "FIRST_MONTH" = {FIRST_MONTH}, 
    "LAST_MONTH" = {LAST_MONTH}, 
    "FIRST_DATE" = '{FIRST_DATE}', 
    "LAST_DATE" = '{LAST_DATE}' 
WHERE "CLIMATE_ID" = '{c_id}';
"""

for index, row in weather_merged_meta_gdf.iterrows():
    statement = update_data_statement(
        row['CLIMATE_ID'],
        row['FIRST_DAY'],
        row['LAST_DAY'],
        row['FIRST_MONTH'],
        row['LAST_MONTH'],
        row['FIRST_DATE'],
        row['LAST_DATE']
    )
    db.execute_sql(statement)
# Out:
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3010010';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3010010';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3010237';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3010237';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3060406';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3060406';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3050519';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3050519';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3030525';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3030525';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2001-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3060535';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2001-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3060535';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3070600';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3070600';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3030720';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3030720';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3010730';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3010730';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3030772';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3030772';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3030768';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3030768';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3050778';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3050778';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1999-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3010816';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1999-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3010816';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3030830';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3030830';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3030QLP';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3030QLP';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3031092';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3031092';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3011240';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3011240';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3031322';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3031322';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3031480';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3031480';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3031640';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3031640';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3074935';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3074935';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3081680';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3081680';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3011815';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3011815';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3031875';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3031875';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3011887';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3011887';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3051R4R';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3051R4R';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3061975';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3061975';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3042045';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3042045';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '30221LG';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '30221LG';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2013-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3012202';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2013-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3012202';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3012216';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3012216';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2001-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '301A001';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2001-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '301A001';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3062246';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3062246';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3012275';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3012275';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3032422';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3032422';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '301B460';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '301B460';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3072525';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3072525';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3032550';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3032550';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3032642';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3032642';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2006-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3072655';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2006-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3072655';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3062697';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3062697';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3072723';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3072723';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '307KPFP';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '307KPFP';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3072921';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3072921';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3063135';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3063135';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3073140';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3073140';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2016-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3063165';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2016-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3063165';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3013340';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3013340';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3023402';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3023402';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3033498';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3033498';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3053536';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3053536';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3013640';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3013640';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3063686';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3063686';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3023722';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3023722';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3033890';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3033890';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3033897';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3033897';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3013959';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3013959';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3074190';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3074190';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3044232';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3044232';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3034485';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3034485';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3064528';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3064528';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3044533';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3044533';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3024668';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3024668';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3014665';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3014665';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '305MGFF';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '305MGFF';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2002-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3054843';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2002-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3054843';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3024925';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3024925';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3014921';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3014921';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3044923';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3044923';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3024965';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3024965';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3075041';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3075041';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3075160';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3075160';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3035198';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3035198';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3025243';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3025243';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3025297';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3025297';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3035422';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3035422';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3025481';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3025481';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2000-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3075488';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2000-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3075488';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3065475';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3065475';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3015523';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3015523';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3025768';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2003-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3025768';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3035845';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3035845';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3065995';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3065995';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3016022';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3016022';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2000-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3076069';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2000-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3076069';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3015676';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3015676';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3036099';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3036099';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3016124';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2004-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3016124';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3036205';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3036205';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3026KNQ';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '3026KNQ';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
# ...
# WHERE "CLIMATE_ID" = '4016566';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4036844';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4036844';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4046884';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4046884';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4057152';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4057152';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4047240';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4047240';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4067655';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4067655';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4067723';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4067723';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4067799';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4067799';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4028060';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4028060';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4028038';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4028038';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '406QLD0';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '406QLD0';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4038412';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4038412';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4068559';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4068559';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4018642';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4018642';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '401HP5R';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '401HP5R';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '40190LN';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '40190LN';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4019075';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '1998-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '4019075';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100181';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100181';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100301';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100301';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100LRP';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100LRP';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100518';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100518';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100630';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100630';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100636';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100636';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100660';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100660';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100693';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100693';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100701';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100701';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100805';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100805';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2007-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100935';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2007-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2100935';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2101102';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2101102';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2101201';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2101201';
#
# Execution started -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2101303';
#
# Exectution completed -->
# UPDATE "weather_metadata"
# SET
#     "FIRST_DAY" = 1,
#     "LAST_DAY" = 31,
#     "FIRST_MONTH" = 1,
#     "LAST_MONTH" = 12,
#     "FIRST_DATE" = '2005-01-01 00:00:00',
#     "LAST_DATE" = '2017-12-31 00:00:00'
# WHERE "CLIMATE_ID" = '2101303';
